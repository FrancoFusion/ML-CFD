# %% [markdown]
# ## Explore data

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

BASE_FOLDER = '400Samples'
MATRIX_ROWS = 101
MATRIX_COLS = 215

def get_sample_files(sample_index, base_folder=BASE_FOLDER):
    files = [f for f in os.listdir(base_folder) if f.startswith(sample_index + '_') and f.endswith('.csv')]
    deltap_file = next((os.path.join(base_folder, f) for f in files if 'deltap' in f.lower()), None)
    geom_file = next((os.path.join(base_folder, f) for f in files if 'geom' in f.lower()), None)
    temp_file = next((os.path.join(base_folder, f) for f in files if 'temp' in f.lower() or 'temperature' in f.lower()), None)
    if not all([deltap_file, geom_file, temp_file]):
        raise FileNotFoundError(f"One or more CSV files missing for sample '{sample_index}'.")
    return {'deltap': deltap_file, 'geom': geom_file, 'temp': temp_file}

def parse_filename(filename):
    base = os.path.splitext(filename)[0]
    parts = base.split('_')
    heat_source = float(parts[-2])
    velocity = float(parts[-1])
    return heat_source, velocity

def load_pressure_drop(deltap_csv):
    df = pd.read_csv(deltap_csv)
    if df.empty:
        raise ValueError(f"Deltap CSV '{deltap_csv}' is empty.")
    return df.iloc[0, 0]

def load_geometry(geom_csv):
    df = pd.read_csv(geom_csv, usecols=['Density (kg/m^3)', 'Y (m)', 'Z (m)'])
    df['Y (m)'] = df['Y (m)'].round(10)
    df['Z (m)'] = df['Z (m)'].round(10)
    df['Geometry'] = np.where(df['Density (kg/m^3)'] < 1500, 1, 0)
    pivot = df.pivot_table(index='Z (m)', columns='Y (m)', values='Geometry', fill_value=0)
    matrix = pivot.values
    if matrix.shape != (MATRIX_ROWS, MATRIX_COLS):
        matrix = np.pad(matrix, 
                        ((0, max(0, MATRIX_ROWS - matrix.shape[0])), 
                         (0, max(0, MATRIX_COLS - matrix.shape[1]))), 
                        'constant', constant_values=0)
        matrix = matrix[:MATRIX_ROWS, :MATRIX_COLS]
    return matrix

def load_temperature(temp_csv):
    df = pd.read_csv(temp_csv, usecols=['Temperature (K)', 'Y (m)', 'Z (m)'])
    df['Y (m)'] = df['Y (m)'].round(10)
    df['Z (m)'] = df['Z (m)'].round(10)
    pivot = df.pivot_table(index='Z (m)', columns='Y (m)', values='Temperature (K)', fill_value=0)
    matrix = pivot.values
    if matrix.shape != (MATRIX_ROWS, MATRIX_COLS):
        matrix = np.pad(matrix, 
                        ((0, max(0, MATRIX_ROWS - matrix.shape[0])), 
                         (0, max(0, MATRIX_COLS - matrix.shape[1]))), 
                        'constant', constant_values=0)
        matrix = matrix[:MATRIX_ROWS, :MATRIX_COLS]
    return matrix

def create_constant_matrix(value, rows=MATRIX_ROWS, cols=MATRIX_COLS):
    return np.full((rows, cols), value)

def plot_matrix(matrix, title, cmap='viridis', label='Value'):
    plt.figure(figsize=(8, 6))
    if np.any(matrix > 0):
        vmin = np.min(matrix[matrix > 0])
        vmax = np.max(matrix)
        plt.imshow(matrix, origin='lower', cmap=cmap, vmin=vmin, vmax=vmax)
    else:
        plt.imshow(matrix, origin='lower', cmap=cmap)
    plt.colorbar(label=label)
    plt.xlabel('Y Index')
    plt.ylabel('Z Index')
    plt.title(title)
    plt.tight_layout()
    plt.show()

def process_sample(sample_index, base_folder=BASE_FOLDER):
    files = get_sample_files(sample_index, base_folder)
    sample_filename = os.path.basename(files['geom'])
    heat_source, velocity = parse_filename(sample_filename)
    pressure_drop = load_pressure_drop(files['deltap'])
    geometry_matrix = load_geometry(files['geom'])
    temperature_matrix = load_temperature(files['temp'])
    velocity_matrix = create_constant_matrix(velocity)
    heat_source_matrix = create_constant_matrix(heat_source)
    plot_matrix(velocity_matrix, 'Velocity', cmap='Blues', label='Velocity')
    plot_matrix(geometry_matrix, 'Geometry', cmap='binary', label='Geometry')
    plot_matrix(heat_source_matrix, 'Heat Source', cmap='Oranges', label='Heat Source (W/m²)')
    plot_matrix(temperature_matrix, 'Temperature', cmap='hot', label='Temperature (K)')
    print(f"Pressure Drop for sample '{sample_index}': {pressure_drop} Pa")

sample_index = '0028'
process_sample(sample_index)
# Out:
# Pressure Drop for sample '0028': 427.5818614740128 Pa

# %% [markdown]
# ## Saving torch tensors

# %%
import os
import pandas as pd
import numpy as np
import torch
from sklearn.model_selection import train_test_split

BASE_FOLDER = '400Samples'
MATRIX_ROWS = 101
MATRIX_COLS = 215

def get_sample_files(sample_index, base_folder=BASE_FOLDER):
    files = [f for f in os.listdir(base_folder) if f.startswith(sample_index + '_') and f.endswith('.csv')]
    deltap_file = next((os.path.join(base_folder, f) for f in files if 'deltap' in f.lower()), None)
    geom_file = next((os.path.join(base_folder, f) for f in files if 'geom' in f.lower()), None)
    temp_file = next((os.path.join(base_folder, f) for f in files if 'temp' in f.lower() or 'temperature' in f.lower()), None)
    if not all([deltap_file, geom_file, temp_file]):
        raise FileNotFoundError(f"One or more CSV files missing for sample '{sample_index}'.")
    return {'deltap': deltap_file, 'geom': geom_file, 'temp': temp_file}

def parse_filename(filename):
    base = os.path.splitext(filename)[0]
    parts = base.split('_')
    heat_source = float(parts[-2])
    velocity = float(parts[-1])
    return heat_source, velocity

def load_pressure_drop(deltap_csv):
    df = pd.read_csv(deltap_csv)
    if df.empty:
        raise ValueError(f"Deltap CSV '{deltap_csv}' is empty.")
    return df.iloc[0, 0]

def load_geometry(geom_csv):
    df = pd.read_csv(geom_csv, usecols=['Density (kg/m^3)', 'Y (m)', 'Z (m)'])
    df['Y (m)'] = df['Y (m)'].round(10)
    df['Z (m)'] = df['Z (m)'].round(10)
    df['Geometry'] = np.where(df['Density (kg/m^3)'] < 1500, 1, 0)
    pivot = df.pivot_table(index='Z (m)', columns='Y (m)', values='Geometry', fill_value=0)
    matrix = pivot.values
    if matrix.shape != (MATRIX_ROWS, MATRIX_COLS):
        matrix = np.pad(matrix, 
                        ((0, max(0, MATRIX_ROWS - matrix.shape[0])), 
                         (0, max(0, MATRIX_COLS - matrix.shape[1]))), 
                        'constant', constant_values=0)
        matrix = matrix[:MATRIX_ROWS, :MATRIX_COLS]
    return matrix

def load_temperature(temp_csv):
    df = pd.read_csv(temp_csv, usecols=['Temperature (K)', 'Y (m)', 'Z (m)'])
    df['Y (m)'] = df['Y (m)'].round(10)
    df['Z (m)'] = df['Z (m)'].round(10)
    pivot = df.pivot_table(index='Z (m)', columns='Y (m)', values='Temperature (K)', fill_value=0)
    matrix = pivot.values
    if matrix.shape != (MATRIX_ROWS, MATRIX_COLS):
        matrix = np.pad(matrix, 
                        ((0, max(0, MATRIX_ROWS - matrix.shape[0])), 
                         (0, max(0, MATRIX_COLS - matrix.shape[1]))), 
                        'constant', constant_values=0)
        matrix = matrix[:MATRIX_ROWS, :MATRIX_COLS]
    return matrix

def create_constant_matrix(value, rows=MATRIX_ROWS, cols=MATRIX_COLS):
    matrix = np.full((rows, cols), value)
    return matrix

def process_sample(sample_index):
    files = get_sample_files(sample_index)
    sample_filename = os.path.basename(files['geom'])
    heat_source, velocity = parse_filename(sample_filename)
    pressure_drop = load_pressure_drop(files['deltap'])
    geometry_matrix = load_geometry(files['geom'])
    temperature_matrix = load_temperature(files['temp'])
    velocity_matrix = create_constant_matrix(velocity)
    heat_source_matrix = create_constant_matrix(heat_source)
    return {
        'heat_source': heat_source_matrix,
        'channel_geometry': geometry_matrix,
        'pressure_drop': pressure_drop,
        'temperature': temperature_matrix,
        'inlet_velocity': velocity_matrix
    }

sample_files = [f for f in os.listdir(BASE_FOLDER) if f.endswith('.csv')]
sample_indices = sorted(list(set(f[:4] for f in sample_files)))

heat_sources = []
channel_geometries = []
pressure_drops = []
temperatures = []
inlet_velocities = []

for idx, sample_index in enumerate(sample_indices):
    try:
        data = process_sample(sample_index)
        heat_sources.append(data['heat_source'])
        channel_geometries.append(data['channel_geometry'])
        pressure_drops.append(data['pressure_drop'])
        temperatures.append(data['temperature'])
        inlet_velocities.append(data['inlet_velocity'])
        print(f"Processed sample {idx+1}/{len(sample_indices)}: {sample_index}")
    except Exception as e:
        print(f"Error processing sample '{sample_index}': {e}")

heat_sources = torch.tensor(heat_sources, dtype=torch.float32)
channel_geometries = torch.tensor(channel_geometries, dtype=torch.float32)
pressure_drops = torch.tensor(pressure_drops, dtype=torch.float32)
temperatures = torch.tensor(temperatures, dtype=torch.float32)
inlet_velocities = torch.tensor(inlet_velocities, dtype=torch.float32)

print("Heat Source tensor shape:", heat_sources.shape)
print("Channel Geometry tensor shape:", channel_geometries.shape)
print("Pressure Drop tensor shape:", pressure_drops.shape)
print("Temperature tensor shape:", temperatures.shape)
print("Inlet Velocity tensor shape:", inlet_velocities.shape)

train_indices, test_indices = train_test_split(range(len(sample_indices)), test_size=0.2, random_state=42)

train_data = {
    'heat_source': heat_sources[train_indices],
    'channel_geometry': channel_geometries[train_indices],
    'pressure_drop': pressure_drops[train_indices],
    'temperature': temperatures[train_indices],
    'inlet_velocity': inlet_velocities[train_indices]
}

test_data = {
    'heat_source': heat_sources[test_indices],
    'channel_geometry': channel_geometries[test_indices],
    'pressure_drop': pressure_drops[test_indices],
    'temperature': temperatures[test_indices],
    'inlet_velocity': inlet_velocities[test_indices]
}

torch.save(train_data, 'M1_training_data.pt')
torch.save(test_data, 'M1_testing_data.pt')

print(f"Total samples: {len(sample_indices)}")
print(f"Training samples: {len(train_indices)}")
print(f"Testing samples: {len(test_indices)}")
# Out:
# Processed sample 1/400: 0001
# Processed sample 2/400: 0002
# Processed sample 3/400: 0003
# Processed sample 4/400: 0004
# Processed sample 5/400: 0005
# Processed sample 6/400: 0006
# Processed sample 7/400: 0007
# Processed sample 8/400: 0008
# Processed sample 9/400: 0009
# Processed sample 10/400: 0010
# Processed sample 11/400: 0011
# Processed sample 12/400: 0012
# Processed sample 13/400: 0013
# Processed sample 14/400: 0014
# Processed sample 15/400: 0015
# Processed sample 16/400: 0016
# Processed sample 17/400: 0017
# Processed sample 18/400: 0018
# Processed sample 19/400: 0019
# Processed sample 20/400: 0020
# Processed sample 21/400: 0021
# Processed sample 22/400: 0022
# Processed sample 23/400: 0023
# Processed sample 24/400: 0024
# Processed sample 25/400: 0025
# Processed sample 26/400: 0026
# Processed sample 27/400: 0027
# Processed sample 28/400: 0028
# Processed sample 29/400: 0029
# Processed sample 30/400: 0030
# Processed sample 31/400: 0031
# Processed sample 32/400: 0032
# Processed sample 33/400: 0033
# Processed sample 34/400: 0034
# Processed sample 35/400: 0035
# Processed sample 36/400: 0036
# Processed sample 37/400: 0037
# Processed sample 38/400: 0038
# Processed sample 39/400: 0039
# Processed sample 40/400: 0040
# Processed sample 41/400: 0041
# Processed sample 42/400: 0042
# Processed sample 43/400: 0043
# Processed sample 44/400: 0044
# Processed sample 45/400: 0045
# Processed sample 46/400: 0046
# Processed sample 47/400: 0047
# Processed sample 48/400: 0048
# Processed sample 49/400: 0049
# Processed sample 50/400: 0050
# Processed sample 51/400: 0051
# Processed sample 52/400: 0052
# Processed sample 53/400: 0053
# Processed sample 54/400: 0054
# Processed sample 55/400: 0055
# Processed sample 56/400: 0056
# Processed sample 57/400: 0057
# Processed sample 58/400: 0058
# Processed sample 59/400: 0059
# Processed sample 60/400: 0060
# Processed sample 61/400: 0061
# Processed sample 62/400: 0062
# Processed sample 63/400: 0063
# Processed sample 64/400: 0064
# Processed sample 65/400: 0065
# Processed sample 66/400: 0066
# Processed sample 67/400: 0067
# Processed sample 68/400: 0068
# Processed sample 69/400: 0069
# Processed sample 70/400: 0070
# Processed sample 71/400: 0071
# Processed sample 72/400: 0072
# Processed sample 73/400: 0073
# Processed sample 74/400: 0074
# Processed sample 75/400: 0075
# Processed sample 76/400: 0076
# Processed sample 77/400: 0077
# Processed sample 78/400: 0078
# Processed sample 79/400: 0079
# Processed sample 80/400: 0080
# Processed sample 81/400: 0081
# Processed sample 82/400: 0082
# Processed sample 83/400: 0083
# Processed sample 84/400: 0084
# Processed sample 85/400: 0085
# Processed sample 86/400: 0086
# Processed sample 87/400: 0087
# Processed sample 88/400: 0088
# Processed sample 89/400: 0089
# Processed sample 90/400: 0090
# Processed sample 91/400: 0091
# Processed sample 92/400: 0092
# Processed sample 93/400: 0093
# Processed sample 94/400: 0094
# Processed sample 95/400: 0095
# Processed sample 96/400: 0096
# Processed sample 97/400: 0097
# Processed sample 98/400: 0098
# Processed sample 99/400: 0099
# Processed sample 100/400: 0100
# Processed sample 101/400: 0101
# Processed sample 102/400: 0102
# Processed sample 103/400: 0103
# Processed sample 104/400: 0104
# Processed sample 105/400: 0105
# Processed sample 106/400: 0106
# Processed sample 107/400: 0107
# Processed sample 108/400: 0108
# Processed sample 109/400: 0109
# Processed sample 110/400: 0110
# Processed sample 111/400: 0111
# Processed sample 112/400: 0112
# Processed sample 113/400: 0113
# Processed sample 114/400: 0114
# Processed sample 115/400: 0115
# Processed sample 116/400: 0116
# Processed sample 117/400: 0117
# Processed sample 118/400: 0118
# Processed sample 119/400: 0119
# Processed sample 120/400: 0120
# Processed sample 121/400: 0121
# Processed sample 122/400: 0122
# Processed sample 123/400: 0123
# Processed sample 124/400: 0124
# Processed sample 125/400: 0125
# Processed sample 126/400: 0126
# Processed sample 127/400: 0127
# Processed sample 128/400: 0128
# Processed sample 129/400: 0129
# Processed sample 130/400: 0130
# Processed sample 131/400: 0131
# Processed sample 132/400: 0132
# Processed sample 133/400: 0133
# Processed sample 134/400: 0134
# Processed sample 135/400: 0135
# Processed sample 136/400: 0136
# Processed sample 137/400: 0137
# Processed sample 138/400: 0138
# Processed sample 139/400: 0139
# Processed sample 140/400: 0140
# Processed sample 141/400: 0141
# Processed sample 142/400: 0142
# Processed sample 143/400: 0143
# Processed sample 144/400: 0144
# Processed sample 145/400: 0145
# Processed sample 146/400: 0146
# Processed sample 147/400: 0147
# Processed sample 148/400: 0148
# Processed sample 149/400: 0149
# Processed sample 150/400: 0150
# Processed sample 151/400: 0151
# Processed sample 152/400: 0152
# Processed sample 153/400: 0153
# Processed sample 154/400: 0154
# Processed sample 155/400: 0155
# Processed sample 156/400: 0156
# Processed sample 157/400: 0157
# Processed sample 158/400: 0158
# Processed sample 159/400: 0159
# Processed sample 160/400: 0160
# Processed sample 161/400: 0161
# Processed sample 162/400: 0162
# Processed sample 163/400: 0163
# Processed sample 164/400: 0164
# Processed sample 165/400: 0165
# Processed sample 166/400: 0166
# Processed sample 167/400: 0167
# Processed sample 168/400: 0168
# Processed sample 169/400: 0169
# Processed sample 170/400: 0170
# Processed sample 171/400: 0171
# Processed sample 172/400: 0172
# Processed sample 173/400: 0173
# Processed sample 174/400: 0174
# Processed sample 175/400: 0175
# Processed sample 176/400: 0176
# Processed sample 177/400: 0177
# Processed sample 178/400: 0178
# Processed sample 179/400: 0179
# Processed sample 180/400: 0180
# Processed sample 181/400: 0181
# Processed sample 182/400: 0182
# Processed sample 183/400: 0183
# Processed sample 184/400: 0184
# Processed sample 185/400: 0185
# Processed sample 186/400: 0186
# Processed sample 187/400: 0187
# Processed sample 188/400: 0188
# Processed sample 189/400: 0189
# Processed sample 190/400: 0190
# Processed sample 191/400: 0191
# Processed sample 192/400: 0192
# Processed sample 193/400: 0193
# Processed sample 194/400: 0194
# Processed sample 195/400: 0195
# Processed sample 196/400: 0196
# Processed sample 197/400: 0197
# Processed sample 198/400: 0198
# Processed sample 199/400: 0199
# Processed sample 200/400: 0200
# Processed sample 201/400: 0201
# Processed sample 202/400: 0202
# Processed sample 203/400: 0203
# Processed sample 204/400: 0204
# Processed sample 205/400: 0205
# Processed sample 206/400: 0206
# Processed sample 207/400: 0207
# Processed sample 208/400: 0208
# Processed sample 209/400: 0209
# Processed sample 210/400: 0210
# Processed sample 211/400: 0211
# Processed sample 212/400: 0212
# Processed sample 213/400: 0213
# Processed sample 214/400: 0214
# Processed sample 215/400: 0215
# Processed sample 216/400: 0216
# Processed sample 217/400: 0217
# Processed sample 218/400: 0218
# Processed sample 219/400: 0219
# Processed sample 220/400: 0220
# Processed sample 221/400: 0221
# Processed sample 222/400: 0222
# Processed sample 223/400: 0223
# Processed sample 224/400: 0224
# Processed sample 225/400: 0225
# Processed sample 226/400: 0226
# Processed sample 227/400: 0227
# Processed sample 228/400: 0228
# Processed sample 229/400: 0229
# Processed sample 230/400: 0230
# Processed sample 231/400: 0231
# Processed sample 232/400: 0232
# Processed sample 233/400: 0233
# Processed sample 234/400: 0234
# Processed sample 235/400: 0235
# Processed sample 236/400: 0236
# Processed sample 237/400: 0237
# Processed sample 238/400: 0238
# Processed sample 239/400: 0239
# Processed sample 240/400: 0240
# Processed sample 241/400: 0241
# Processed sample 242/400: 0242
# Processed sample 243/400: 0243
# Processed sample 244/400: 0244
# Processed sample 245/400: 0245
# Processed sample 246/400: 0246
# Processed sample 247/400: 0247
# Processed sample 248/400: 0248
# Processed sample 249/400: 0249
# Processed sample 250/400: 0250
# Processed sample 251/400: 0251
# Processed sample 252/400: 0252
# Processed sample 253/400: 0253
# Processed sample 254/400: 0254
# Processed sample 255/400: 0255
# Processed sample 256/400: 0256
# Processed sample 257/400: 0257
# Processed sample 258/400: 0258
# Processed sample 259/400: 0259
# Processed sample 260/400: 0260
# Processed sample 261/400: 0261
# Processed sample 262/400: 0262
# Processed sample 263/400: 0263
# Processed sample 264/400: 0264
# Processed sample 265/400: 0265
# Processed sample 266/400: 0266
# Processed sample 267/400: 0267
# Processed sample 268/400: 0268
# Processed sample 269/400: 0269
# Processed sample 270/400: 0270
# Processed sample 271/400: 0271
# Processed sample 272/400: 0272
# Processed sample 273/400: 0273
# Processed sample 274/400: 0274
# Processed sample 275/400: 0275
# Processed sample 276/400: 0276
# Processed sample 277/400: 0277
# Processed sample 278/400: 0278
# Processed sample 279/400: 0279
# Processed sample 280/400: 0280
# Processed sample 281/400: 0281
# Processed sample 282/400: 0282
# Processed sample 283/400: 0283
# Processed sample 284/400: 0284
# Processed sample 285/400: 0285
# Processed sample 286/400: 0286
# Processed sample 287/400: 0287
# Processed sample 288/400: 0288
# Processed sample 289/400: 0289
# Processed sample 290/400: 0290
# Processed sample 291/400: 0291
# Processed sample 292/400: 0292
# Processed sample 293/400: 0293
# Processed sample 294/400: 0294
# Processed sample 295/400: 0295
# Processed sample 296/400: 0296
# Processed sample 297/400: 0297
# Processed sample 298/400: 0298
# Processed sample 299/400: 0299
# Processed sample 300/400: 0300
# Processed sample 301/400: 0301
# Processed sample 302/400: 0302
# Processed sample 303/400: 0303
# Processed sample 304/400: 0304
# Processed sample 305/400: 0305
# Processed sample 306/400: 0306
# Processed sample 307/400: 0307
# Processed sample 308/400: 0308
# Processed sample 309/400: 0309
# Processed sample 310/400: 0310
# Processed sample 311/400: 0311
# Processed sample 312/400: 0312
# Processed sample 313/400: 0313
# Processed sample 314/400: 0314
# Processed sample 315/400: 0315
# Processed sample 316/400: 0316
# Processed sample 317/400: 0317
# Processed sample 318/400: 0318
# Processed sample 319/400: 0319
# Processed sample 320/400: 0320
# Processed sample 321/400: 0321
# Processed sample 322/400: 0322
# Processed sample 323/400: 0323
# Processed sample 324/400: 0324
# Processed sample 325/400: 0325
# Processed sample 326/400: 0326
# Processed sample 327/400: 0327
# Processed sample 328/400: 0328
# Processed sample 329/400: 0329
# Processed sample 330/400: 0330
# Processed sample 331/400: 0331
# Processed sample 332/400: 0332
# Processed sample 333/400: 0333
# Processed sample 334/400: 0334
# Processed sample 335/400: 0335
# Processed sample 336/400: 0336
# Processed sample 337/400: 0337
# Processed sample 338/400: 0338
# Processed sample 339/400: 0339
# Processed sample 340/400: 0340
# Processed sample 341/400: 0341
# Processed sample 342/400: 0342
# Processed sample 343/400: 0343
# Processed sample 344/400: 0344
# Processed sample 345/400: 0345
# Processed sample 346/400: 0346
# Processed sample 347/400: 0347
# Processed sample 348/400: 0348
# Processed sample 349/400: 0349
# Processed sample 350/400: 0350
# Processed sample 351/400: 0351
# Processed sample 352/400: 0352
# Processed sample 353/400: 0353
# Processed sample 354/400: 0354
# Processed sample 355/400: 0355
# Processed sample 356/400: 0356
# Processed sample 357/400: 0357
# Processed sample 358/400: 0358
# Processed sample 359/400: 0359
# Processed sample 360/400: 0360
# Processed sample 361/400: 0361
# Processed sample 362/400: 0362
# Processed sample 363/400: 0363
# Processed sample 364/400: 0364
# Processed sample 365/400: 0365
# Processed sample 366/400: 0366
# Processed sample 367/400: 0367
# Processed sample 368/400: 0368
# Processed sample 369/400: 0369
# Processed sample 370/400: 0370
# Processed sample 371/400: 0371
# Processed sample 372/400: 0372
# Processed sample 373/400: 0373
# Processed sample 374/400: 0374
# Processed sample 375/400: 0375
# Processed sample 376/400: 0376
# Processed sample 377/400: 0377
# Processed sample 378/400: 0378
# Processed sample 379/400: 0379
# Processed sample 380/400: 0380
# Processed sample 381/400: 0381
# Processed sample 382/400: 0382
# Processed sample 383/400: 0383
# Processed sample 384/400: 0384
# Processed sample 385/400: 0385
# Processed sample 386/400: 0386
# Processed sample 387/400: 0387
# Processed sample 388/400: 0388
# Processed sample 389/400: 0389
# Processed sample 390/400: 0390
# Processed sample 391/400: 0391
# Processed sample 392/400: 0392
# Processed sample 393/400: 0393
# Processed sample 394/400: 0394
# Processed sample 395/400: 0395
# Processed sample 396/400: 0396
# Processed sample 397/400: 0397
# Processed sample 398/400: 0398
# Processed sample 399/400: 0399
# Processed sample 400/400: 0400
# C:\Users\franc\AppData\Local\Temp\ipykernel_11560\3874053739.py:104: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ..\torch\csrc\utils\tensor_new.cpp:248.)
#   heat_sources = torch.tensor(heat_sources, dtype=torch.float32)
# Heat Source tensor shape: torch.Size([400, 101, 215])
# Channel Geometry tensor shape: torch.Size([400, 101, 215])
# Pressure Drop tensor shape: torch.Size([400])
# Temperature tensor shape: torch.Size([400, 101, 215])
# Inlet Velocity tensor shape: torch.Size([400, 101, 215])
# Total samples: 400
# Training samples: 320
# Testing samples: 80
