# %% [markdown]
# ## Explore data

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

BASE_FOLDER = 'tempo'
MATRIX_ROWS = 101
MATRIX_COLS = 215

def get_sample_files(sample_index, base_folder=BASE_FOLDER):
    files = [f for f in os.listdir(base_folder) if f.startswith(sample_index + '_') and f.endswith('.csv')]
    deltap_file = next((os.path.join(base_folder, f) for f in files if 'deltap' in f.lower()), None)
    geom_file = next((os.path.join(base_folder, f) for f in files if 'geom' in f.lower()), None)
    temp_file = next((os.path.join(base_folder, f) for f in files if 'temp' in f.lower() or 'temperature' in f.lower()), None)
    if not all([deltap_file, geom_file, temp_file]):
        raise FileNotFoundError(f"One or more CSV files missing for sample '{sample_index}'.")
    return {'deltap': deltap_file, 'geom': geom_file, 'temp': temp_file}

def parse_filename(filename):
    base = os.path.splitext(filename)[0]
    parts = base.split('_')
    heat_source = float(parts[-2])
    velocity = float(parts[-1])
    return heat_source, velocity

def load_pressure_drop(deltap_csv):
    df = pd.read_csv(deltap_csv)
    if df.empty:
        raise ValueError(f"Deltap CSV '{deltap_csv}' is empty.")
    return df.iloc[0, 0]

def load_geometry(geom_csv):
    df = pd.read_csv(geom_csv, usecols=['Density (kg/m^3)', 'Y (m)', 'Z (m)'])
    df['Y (m)'] = df['Y (m)'].round(10)
    df['Z (m)'] = df['Z (m)'].round(10)
    df['Geometry'] = np.where(df['Density (kg/m^3)'] < 1500, 1, 0)
    pivot = df.pivot_table(index='Z (m)', columns='Y (m)', values='Geometry', fill_value=0)
    matrix = pivot.values
    if matrix.shape != (MATRIX_ROWS, MATRIX_COLS):
        matrix = np.pad(matrix, 
                        ((0, max(0, MATRIX_ROWS - matrix.shape[0])), 
                         (0, max(0, MATRIX_COLS - matrix.shape[1]))), 
                        'constant', constant_values=0)
        matrix = matrix[:MATRIX_ROWS, :MATRIX_COLS]
    return matrix

def load_temperature(temp_csv):
    df = pd.read_csv(temp_csv, usecols=['Temperature (K)', 'Y (m)', 'Z (m)'])
    df['Y (m)'] = df['Y (m)'].round(10)
    df['Z (m)'] = df['Z (m)'].round(10)
    pivot = df.pivot_table(index='Z (m)', columns='Y (m)', values='Temperature (K)', fill_value=0)
    matrix = pivot.values
    if matrix.shape != (MATRIX_ROWS, MATRIX_COLS):
        matrix = np.pad(matrix, 
                        ((0, max(0, MATRIX_ROWS - matrix.shape[0])), 
                         (0, max(0, MATRIX_COLS - matrix.shape[1]))), 
                        'constant', constant_values=0)
        matrix = matrix[:MATRIX_ROWS, :MATRIX_COLS]
    return matrix

def create_constant_matrix(value, rows=MATRIX_ROWS, cols=MATRIX_COLS):
    return np.full((rows, cols), value)

def plot_matrix(matrix, title, cmap='viridis', label='Value'):
    plt.figure(figsize=(8, 6))
    if np.any(matrix > 0):
        vmin = np.min(matrix[matrix > 0])
        vmax = np.max(matrix)
        plt.imshow(matrix, origin='lower', cmap=cmap, vmin=vmin, vmax=vmax)
    else:
        plt.imshow(matrix, origin='lower', cmap=cmap)
    plt.colorbar(label=label)
    plt.xlabel('Y Index')
    plt.ylabel('Z Index')
    plt.title(title)
    plt.tight_layout()
    plt.show()

def process_sample(sample_index, base_folder=BASE_FOLDER):
    files = get_sample_files(sample_index, base_folder)
    sample_filename = os.path.basename(files['geom'])
    heat_source, velocity = parse_filename(sample_filename)
    pressure_drop = load_pressure_drop(files['deltap'])
    geometry_matrix = load_geometry(files['geom'])
    temperature_matrix = load_temperature(files['temp'])
    velocity_matrix = create_constant_matrix(velocity)
    heat_source_matrix = create_constant_matrix(heat_source)
    plot_matrix(velocity_matrix, 'Velocity', cmap='Blues', label='Velocity')
    plot_matrix(geometry_matrix, 'Geometry', cmap='binary', label='Geometry')
    plot_matrix(heat_source_matrix, 'Heat Source', cmap='Oranges', label='Heat Source (W/m²)')
    plot_matrix(temperature_matrix, 'Temperature', cmap='hot', label='Temperature (K)')
    print(f"Pressure Drop for sample '{sample_index}': {pressure_drop} Pa")

sample_index = '0007'
process_sample(sample_index)
# Out:
# Pressure Drop for sample '0007': 778.6722730463517 Pa

# %% [markdown]
# ## Saving torch tensors

# %%
import os
import pandas as pd
import numpy as np
import torch
from sklearn.model_selection import train_test_split

BASE_FOLDER = 'tempo'
MATRIX_ROWS = 101
MATRIX_COLS = 215

def get_sample_files(sample_index, base_folder=BASE_FOLDER):
    files = [f for f in os.listdir(base_folder) if f.startswith(sample_index + '_') and f.endswith('.csv')]
    deltap_file = next((os.path.join(base_folder, f) for f in files if 'deltap' in f.lower()), None)
    geom_file = next((os.path.join(base_folder, f) for f in files if 'geom' in f.lower()), None)
    temp_file = next((os.path.join(base_folder, f) for f in files if 'temp' in f.lower() or 'temperature' in f.lower()), None)
    if not all([deltap_file, geom_file, temp_file]):
        raise FileNotFoundError(f"One or more CSV files missing for sample '{sample_index}'.")
    return {'deltap': deltap_file, 'geom': geom_file, 'temp': temp_file}

def parse_filename(filename):
    base = os.path.splitext(filename)[0]
    parts = base.split('_')
    heat_source = float(parts[-2])
    velocity = float(parts[-1])
    return heat_source, velocity

def load_pressure_drop(deltap_csv):
    df = pd.read_csv(deltap_csv)
    if df.empty:
        raise ValueError(f"Deltap CSV '{deltap_csv}' is empty.")
    return df.iloc[0, 0]

def load_geometry(geom_csv):
    df = pd.read_csv(geom_csv, usecols=['Density (kg/m^3)', 'Y (m)', 'Z (m)'])
    df['Y (m)'] = df['Y (m)'].round(10)
    df['Z (m)'] = df['Z (m)'].round(10)
    df['Geometry'] = np.where(df['Density (kg/m^3)'] < 1500, 1, 0)
    pivot = df.pivot_table(index='Z (m)', columns='Y (m)', values='Geometry', fill_value=0)
    matrix = pivot.values
    if matrix.shape != (MATRIX_ROWS, MATRIX_COLS):
        matrix = np.pad(matrix, 
                        ((0, max(0, MATRIX_ROWS - matrix.shape[0])), 
                         (0, max(0, MATRIX_COLS - matrix.shape[1]))), 
                        'constant', constant_values=0)
        matrix = matrix[:MATRIX_ROWS, :MATRIX_COLS]
    return matrix

def load_temperature(temp_csv):
    df = pd.read_csv(temp_csv, usecols=['Temperature (K)', 'Y (m)', 'Z (m)'])
    df['Y (m)'] = df['Y (m)'].round(10)
    df['Z (m)'] = df['Z (m)'].round(10)
    pivot = df.pivot_table(index='Z (m)', columns='Y (m)', values='Temperature (K)', fill_value=0)
    matrix = pivot.values
    if matrix.shape != (MATRIX_ROWS, MATRIX_COLS):
        matrix = np.pad(matrix, 
                        ((0, max(0, MATRIX_ROWS - matrix.shape[0])), 
                         (0, max(0, MATRIX_COLS - matrix.shape[1]))), 
                        'constant', constant_values=0)
        matrix = matrix[:MATRIX_ROWS, :MATRIX_COLS]
    return matrix

def create_constant_matrix(value, rows=MATRIX_ROWS, cols=MATRIX_COLS):
    matrix = np.full((rows, cols), value)
    return matrix

def process_sample(sample_index):
    files = get_sample_files(sample_index)
    sample_filename = os.path.basename(files['geom'])
    heat_source, velocity = parse_filename(sample_filename)
    pressure_drop = load_pressure_drop(files['deltap'])
    geometry_matrix = load_geometry(files['geom'])
    temperature_matrix = load_temperature(files['temp'])
    velocity_matrix = create_constant_matrix(velocity)
    heat_source_matrix = create_constant_matrix(heat_source)
    return {
        'heat_source': heat_source_matrix,
        'channel_geometry': geometry_matrix,
        'pressure_drop': pressure_drop,
        'temperature': temperature_matrix,
        'inlet_velocity': velocity_matrix
    }

sample_files = [f for f in os.listdir(BASE_FOLDER) if f.endswith('.csv')]
sample_indices = sorted(list(set(f[:4] for f in sample_files)))

heat_sources = []
channel_geometries = []
pressure_drops = []
temperatures = []
inlet_velocities = []

for idx, sample_index in enumerate(sample_indices):
    try:
        data = process_sample(sample_index)
        heat_sources.append(data['heat_source'])
        channel_geometries.append(data['channel_geometry'])
        pressure_drops.append(data['pressure_drop'])
        temperatures.append(data['temperature'])
        inlet_velocities.append(data['inlet_velocity'])
        print(f"Processed sample {idx+1}/{len(sample_indices)}: {sample_index}")
    except Exception as e:
        print(f"Error processing sample '{sample_index}': {e}")

heat_sources = torch.tensor(heat_sources, dtype=torch.float32)
channel_geometries = torch.tensor(channel_geometries, dtype=torch.float32)
pressure_drops = torch.tensor(pressure_drops, dtype=torch.float32)
temperatures = torch.tensor(temperatures, dtype=torch.float32)
inlet_velocities = torch.tensor(inlet_velocities, dtype=torch.float32)

print("Heat Source tensor shape:", heat_sources.shape)
print("Channel Geometry tensor shape:", channel_geometries.shape)
print("Pressure Drop tensor shape:", pressure_drops.shape)
print("Temperature tensor shape:", temperatures.shape)
print("Inlet Velocity tensor shape:", inlet_velocities.shape)

train_indices, test_indices = train_test_split(range(len(sample_indices)), test_size=0.2, random_state=42)

train_data = {
    'heat_source': heat_sources[train_indices],
    'channel_geometry': channel_geometries[train_indices],
    'pressure_drop': pressure_drops[train_indices],
    'temperature': temperatures[train_indices],
    'inlet_velocity': inlet_velocities[train_indices]
}

test_data = {
    'heat_source': heat_sources[test_indices],
    'channel_geometry': channel_geometries[test_indices],
    'pressure_drop': pressure_drops[test_indices],
    'temperature': temperatures[test_indices],
    'inlet_velocity': inlet_velocities[test_indices]
}

torch.save(train_data, 'M1_training_data.pt')
torch.save(test_data, 'M1_testing_data.pt')

print(f"Total samples: {len(sample_indices)}")
print(f"Training samples: {len(train_indices)}")
print(f"Testing samples: {len(test_indices)}")
# Out:
# Processed sample 1/238: 0001
# Processed sample 2/238: 0002
# Processed sample 3/238: 0003
# Processed sample 4/238: 0004
# Processed sample 5/238: 0005
# Processed sample 6/238: 0006
# Processed sample 7/238: 0007
# Processed sample 8/238: 0008
# Processed sample 9/238: 0009
# Processed sample 10/238: 0010
# Processed sample 11/238: 0011
# Processed sample 12/238: 0012
# Processed sample 13/238: 0013
# Processed sample 14/238: 0014
# Processed sample 15/238: 0015
# Processed sample 16/238: 0016
# Processed sample 17/238: 0017
# Processed sample 18/238: 0018
# Processed sample 19/238: 0019
# Processed sample 20/238: 0020
# Processed sample 21/238: 0021
# Processed sample 22/238: 0022
# Processed sample 23/238: 0023
# Processed sample 24/238: 0024
# Processed sample 25/238: 0025
# Processed sample 26/238: 0026
# Processed sample 27/238: 0027
# Processed sample 28/238: 0028
# Processed sample 29/238: 0029
# Processed sample 30/238: 0030
# Processed sample 31/238: 0031
# Processed sample 32/238: 0032
# Processed sample 33/238: 0033
# Processed sample 34/238: 0034
# Processed sample 35/238: 0035
# Processed sample 36/238: 0036
# Processed sample 37/238: 0037
# Processed sample 38/238: 0038
# Processed sample 39/238: 0039
# Processed sample 40/238: 0040
# Processed sample 41/238: 0041
# Processed sample 42/238: 0042
# Processed sample 43/238: 0043
# Processed sample 44/238: 0044
# Processed sample 45/238: 0045
# Processed sample 46/238: 0046
# Processed sample 47/238: 0047
# Processed sample 48/238: 0048
# Processed sample 49/238: 0049
# Processed sample 50/238: 0050
# Processed sample 51/238: 0051
# Processed sample 52/238: 0052
# Processed sample 53/238: 0053
# Processed sample 54/238: 0054
# Processed sample 55/238: 0055
# Processed sample 56/238: 0056
# Processed sample 57/238: 0057
# Processed sample 58/238: 0058
# Processed sample 59/238: 0059
# Processed sample 60/238: 0060
# Processed sample 61/238: 0061
# Processed sample 62/238: 0062
# Processed sample 63/238: 0063
# Processed sample 64/238: 0064
# Processed sample 65/238: 0065
# Processed sample 66/238: 0066
# Processed sample 67/238: 0067
# Processed sample 68/238: 0068
# Processed sample 69/238: 0069
# Processed sample 70/238: 0070
# Processed sample 71/238: 0071
# Processed sample 72/238: 0072
# Processed sample 73/238: 0073
# Processed sample 74/238: 0074
# Processed sample 75/238: 0075
# Processed sample 76/238: 0076
# Processed sample 77/238: 0077
# Processed sample 78/238: 0078
# Processed sample 79/238: 0079
# Processed sample 80/238: 0080
# Processed sample 81/238: 0081
# Processed sample 82/238: 0082
# Processed sample 83/238: 0083
# Processed sample 84/238: 0084
# Processed sample 85/238: 0085
# Processed sample 86/238: 0086
# Processed sample 87/238: 0087
# Processed sample 88/238: 0088
# Processed sample 89/238: 0089
# Processed sample 90/238: 0090
# Processed sample 91/238: 0091
# Processed sample 92/238: 0092
# Processed sample 93/238: 0093
# Processed sample 94/238: 0094
# Processed sample 95/238: 0095
# Processed sample 96/238: 0096
# Processed sample 97/238: 0097
# Processed sample 98/238: 0098
# Processed sample 99/238: 0099
# Processed sample 100/238: 0100
# Processed sample 101/238: 0101
# Processed sample 102/238: 0102
# Processed sample 103/238: 0103
# Processed sample 104/238: 0104
# Processed sample 105/238: 0105
# Processed sample 106/238: 0106
# Processed sample 107/238: 0107
# Processed sample 108/238: 0108
# Processed sample 109/238: 0109
# Processed sample 110/238: 0110
# Processed sample 111/238: 0111
# Processed sample 112/238: 0112
# Processed sample 113/238: 0113
# Processed sample 114/238: 0114
# Processed sample 115/238: 0115
# Processed sample 116/238: 0116
# Processed sample 117/238: 0117
# Processed sample 118/238: 0118
# Processed sample 119/238: 0119
# Processed sample 120/238: 0120
# Processed sample 121/238: 0121
# Processed sample 122/238: 0122
# Processed sample 123/238: 0123
# Processed sample 124/238: 0124
# Processed sample 125/238: 0125
# Processed sample 126/238: 0126
# Processed sample 127/238: 0127
# Processed sample 128/238: 0128
# Processed sample 129/238: 0129
# Processed sample 130/238: 0130
# Processed sample 131/238: 0131
# Processed sample 132/238: 0132
# Processed sample 133/238: 0133
# Processed sample 134/238: 0134
# Processed sample 135/238: 0135
# Processed sample 136/238: 0136
# Processed sample 137/238: 0137
# Processed sample 138/238: 0138
# Processed sample 139/238: 0139
# Processed sample 140/238: 0140
# Processed sample 141/238: 0141
# Processed sample 142/238: 0142
# Processed sample 143/238: 0143
# Processed sample 144/238: 0144
# Processed sample 145/238: 0145
# Processed sample 146/238: 0146
# Processed sample 147/238: 0147
# Processed sample 148/238: 0148
# Processed sample 149/238: 0149
# Processed sample 150/238: 0150
# Processed sample 151/238: 0151
# Processed sample 152/238: 0152
# Processed sample 153/238: 0153
# Processed sample 154/238: 0154
# Processed sample 155/238: 0155
# Processed sample 156/238: 0156
# Processed sample 157/238: 0157
# Processed sample 158/238: 0158
# Processed sample 159/238: 0159
# Processed sample 160/238: 0160
# Processed sample 161/238: 0161
# Processed sample 162/238: 0162
# Processed sample 163/238: 0163
# Processed sample 164/238: 0164
# Processed sample 165/238: 0165
# Processed sample 166/238: 0166
# Processed sample 167/238: 0167
# Processed sample 168/238: 0168
# Processed sample 169/238: 0169
# Processed sample 170/238: 0170
# Processed sample 171/238: 0171
# Processed sample 172/238: 0172
# Processed sample 173/238: 0173
# Processed sample 174/238: 0174
# Processed sample 175/238: 0175
# Processed sample 176/238: 0176
# Processed sample 177/238: 0177
# Processed sample 178/238: 0178
# Processed sample 179/238: 0179
# Processed sample 180/238: 0180
# Processed sample 181/238: 0181
# Processed sample 182/238: 0182
# Processed sample 183/238: 0183
# Processed sample 184/238: 0184
# Processed sample 185/238: 0185
# Processed sample 186/238: 0186
# Processed sample 187/238: 0187
# Processed sample 188/238: 0188
# Processed sample 189/238: 0189
# Processed sample 190/238: 0190
# Processed sample 191/238: 0191
# Processed sample 192/238: 0192
# Processed sample 193/238: 0193
# Processed sample 194/238: 0194
# Processed sample 195/238: 0195
# Processed sample 196/238: 0196
# Processed sample 197/238: 0197
# Processed sample 198/238: 0198
# Processed sample 199/238: 0199
# Processed sample 200/238: 0200
# Processed sample 201/238: 0201
# Processed sample 202/238: 0202
# Processed sample 203/238: 0203
# Processed sample 204/238: 0204
# Processed sample 205/238: 0205
# Processed sample 206/238: 0206
# Processed sample 207/238: 0207
# Processed sample 208/238: 0208
# Processed sample 209/238: 0209
# Processed sample 210/238: 0210
# Processed sample 211/238: 0211
# Processed sample 212/238: 0212
# Processed sample 213/238: 0213
# Processed sample 214/238: 0214
# Processed sample 215/238: 0215
# Processed sample 216/238: 0216
# Processed sample 217/238: 0217
# Processed sample 218/238: 0218
# Processed sample 219/238: 0219
# Processed sample 220/238: 0220
# Processed sample 221/238: 0221
# Processed sample 222/238: 0222
# Processed sample 223/238: 0223
# Processed sample 224/238: 0224
# Processed sample 225/238: 0225
# Processed sample 226/238: 0226
# Processed sample 227/238: 0227
# Processed sample 228/238: 0228
# Processed sample 229/238: 0229
# Processed sample 230/238: 0230
# Processed sample 231/238: 0231
# Processed sample 232/238: 0232
# Processed sample 233/238: 0233
# Processed sample 234/238: 0234
# Processed sample 235/238: 0235
# Processed sample 236/238: 0236
# Processed sample 237/238: 0237
# Processed sample 238/238: 0238
# C:\Users\franc\AppData\Local\Temp\ipykernel_16524\2325884983.py:104: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ..\torch\csrc\utils\tensor_new.cpp:248.)
#   heat_sources = torch.tensor(heat_sources, dtype=torch.float32)
# Heat Source tensor shape: torch.Size([238, 101, 215])
# Channel Geometry tensor shape: torch.Size([238, 101, 215])
# Pressure Drop tensor shape: torch.Size([238])
# Temperature tensor shape: torch.Size([238, 101, 215])
# Inlet Velocity tensor shape: torch.Size([238, 101, 215])
# Total samples: 238
# Training samples: 190
# Testing samples: 48
